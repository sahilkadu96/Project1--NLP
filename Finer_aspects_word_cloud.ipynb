# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('G:\Omdena\AI for Habit building using recipes of soft skills\Excels\Finer_aspect_v2.xlsx')
df
# Out:
#                                        Skills category Skills sub-category  \
# 0    Communication collaboration and emotional inte...       Collaboration
# 1    Communication collaboration and emotional inte...       Collaboration
# 2    Communication collaboration and emotional inte...       Collaboration
# 3    Communication collaboration and emotional inte...       Collaboration
# 4    Communication collaboration and emotional inte...       Collaboration
# ..                                                 ...                 ...
# 187  Management planning organization Startegic vis...          Leadership
# 188  Management planning organization Startegic vis...          Leadership
# 189  Management planning organization Startegic vis...          Leadership
# 190  Management planning organization Startegic vis...          Leadership
# 191  Management planning organization Startegic vis...          Leadership
#
# ...

# %%
contents = df[df['Finer aspects'] == 'Adaptability']['Content'].values
contents
# Out:
# array(['Adaptability is a soft skill that means you easily adjust to changing circumstances. An adaptable person in the workplace can keep up with moving priorities, projects, clients, and technology. They’re skilled at dealing with changes at work, whether process updates or their work environment.',
#        'If you’re someone who loves processes and order, it can be hard to stray from what you’ve always done. But just because something has worked for a while doesn’t mean it will be the most useful thing forever. Challenge yourself to try new things, whether a new project management tool or a new way to structure a meeting.\nGet comfortable being uncomfortable.',
# ...

# %%
words = []
stopwords = set(STOPWORDS)

for content in contents:
    tokens = content.split()
    #print(tokens)
    
    for i in range(len(tokens)):
        if tokens[i] not in stopwords:
            words.append(tokens[i])

words
# Out:
# ['Adaptability',
#  'soft',
#  'skill',
#  'means',
#  'easily',
#  'adjust',
#  'changing',
#  'circumstances.',
#  'An',
#  'adaptable',
#  'person',
#  'workplace',
#  'keep',
#  'moving',
#  'priorities,',
#  'projects,',
#  'clients,',
#  'technology.',
#  'They’re',
#  'skilled',
#  'dealing',
#  'changes',
#  'work,',
#  'whether',
#  'process',
#  'updates',
#  'work',
#  'environment.',
#  'If',
#  'you’re',
#  'someone',
#  'loves',
#  'processes',
#  'order,',
#  'hard',
#  'stray',
#  'you’ve',
#  'always',
#  'done.',
#  'But',
#  'something',
#  'worked',
#  'doesn’t',
#  'mean',
#  'will',
#  'useful',
#  'thing',
#  'forever.',
#  'Challenge',
#  'try',
#  'new',
#  'things,',
#  'whether',
#  'new',
#  'project',
#  'management',
#  'tool',
#  'new',
#  'way',
#  'structure',
#  'meeting.',
#  'Get',
#  'comfortable',
#  'uncomfortable.',
#  'A',
#  'growth',
#  'mindset',
#  'vital',
#  'part',
#  'adaptability,',
#  'it’s',
#  'essential',
#  'keep',
# ...

# %%
stri = ''
for i in words:
    stri += i + ' '
stri
# Out:
# "Adaptability soft skill means easily adjust changing circumstances. An adaptable person workplace keep moving priorities, projects, clients, technology. They’re skilled dealing changes work, whether process updates work environment. If you’re someone loves processes order, hard stray you’ve always done. But something worked doesn’t mean will useful thing forever. Challenge try new things, whether new project management tool new way structure meeting. Get comfortable uncomfortable. A growth mindset vital part adaptability, it’s essential keep learning much possible. Stay updated what’s going industry signing newsletters, following top leaders social media, staying connected professionals. You may learn new technology industry trend come handy facing new challenge. Change isn’t steady predictable anyone, including adaptable people. Adaptable individuals need empathetic kinds people respond changing circumstances know listen respond tensions might face. To cultivate empathy, start gett
# ...

# %%
t = contents[0].split()
t[1]
# Out:
# 'is'

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(stri)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
#plt.axis("off")
#plt.tight_layout(pad = 0)
 
plt.show()
